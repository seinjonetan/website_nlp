# %%
from pattern.web import Wikipedia, plaintext
from pattern.en import sentiment

# Fetch the text of the Wikipedia article
article = Wikipedia().article('Artificial Intelligence')
text = plaintext(article.string)

# Analyze the sentiment of the text
sentiment_score = sentiment(text)

print('Sentiment score:', sentiment_score)
# Out:
# Sentiment score: (0.0413736939997445, 0.4914729770696167)

# %%
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.naive_bayes import MultinomialNB
from sklearn.pipeline import make_pipeline
from pattern.web import Wikipedia, plaintext

# Create a list of (title, sentiment) tuples
# data = [
#     ("Healthcare", "positive"),
#     ("Warfare", "negative"),
#     ("Ethical Concerns", "negative"),
#     ("Improve Life", "positive"),
#     # Add more articles here...
# ]

data = [
    ("Artificial Intelligence", "positive"),
    ("Machine Learning", "positive"),
    ("Deep Learning", "positive"),
    ("Computer Science", "negative"),
    # Add more articles here...
]

# Fetch the text of the Wikipedia articles and associate it with the sentiment
data = [(plaintext(Wikipedia().article(title).string), sentiment) for title, sentiment in data]

# Split the data into the texts and the sentiments
texts, sentiments = zip(*data)

# Create a pipeline that converts the texts to a bag-of-words representation and then applies a Naive Bayes classifier
model = make_pipeline(CountVectorizer(), MultinomialNB())

# Train the model on the data
model.fit(texts, sentiments)

# Classify a new article
new_article = plaintext(Wikipedia().article('Artificial Intelligence').string)
print(model.predict([new_article]))
# Out:
# ['positive']

# %%
from pattern.web import Crawler, DEPTH
from pattern.en import sentiment

class PoliticoCrawler(Crawler):
    def visit(self, link, source=None):
        print("visiting: %s from: %s" % (link.url, link.referrer))
        if source:  # If the source is HTML
            s = sentiment(source)
            print("sentiment: %s" % str(s))

    def fail(self, link):
        print("failed: %s" % link.url)

# Create a new crawler.
crawler = PoliticoCrawler(links=["https://www.bbc.com/"], domains=["bbc.com"], delay=1)

while len(crawler.visited) < 100:  # Crawler.visited is a dictionary of all URL's visited so far.
    crawler.crawl(cached=True, throttle=5)
# Out:
# visiting: https://www.bbc.com/ from:
# sentiment: (0.10392193982190648, 0.42923732772108264)
# visiting: https://www.bbc.com/news from: https://www.bbc.com/
# sentiment: (0.08329913676238326, 0.37323594321864184)
# visiting: https://www.bbc.com/sport from: https://www.bbc.com/
# sentiment: (0.1162070755820756, 0.3307037557037555)
# visiting: https://www.bbc.com/business from: https://www.bbc.com/
# sentiment: (0.05951350087637523, 0.42287673821007177)
# visiting: https://www.bbc.com/innovation from: https://www.bbc.com/
# sentiment: (0.06766936896672382, 0.4077020297709952)
# visiting: https://www.bbc.com/culture from: https://www.bbc.com/
# sentiment: (0.14561828211386496, 0.38211232627022096)
# visiting: https://www.bbc.com/travel from: https://www.bbc.com/
# sentiment: (0.14852557163509694, 0.4231848931013276)
# visiting: https://www.bbc.com/future-planet from: https://www.bbc.com/
# sentiment: (0.07119074859989344, 0.4354118104118101)
# visiting: https://www.bbc.com/video from: https://www.bbc.com/
# sentiment: (0.130035422290343, 0.43383989097322445)
# visiting: https://www.bbc.com/live from: https://www.bbc.com/
# sentiment: (0.09325808422317444, 0.4077887883575085)
# visiting: https://www.bbc.com/home from: https://www.bbc.com/
# sentiment: (0.18582956967453437, 0.3746904940367838)
# visiting: https://www.bbc.com/news/topics/c2vdnvdg6xxt from: https://www.bbc.com/
# sentiment: (0.02736699361482965, 0.337293388429752)
# visiting: https://www.bbc.com/news/war-in-ukraine from: https://www.bbc.com/
# sentiment: (0.0387504244842094, 0.2814939918078932)
# visiting: https://www.bbc.com/news/world from: https://www.bbc.com/
# sentiment: (0.0395349217765251, 0.37253401360544214)
# visiting: https://www.bbc.com/news/world/africa from: https://www.bbc.com/
# sentiment: (0.06427109379751139, 0.31523839310536556)
# visiting: https://www.bbc.com/news/world/asia from: https://www.bbc.com/
# sentiment: (0.030347452391659098, 0.414743318275927)
# visiting: https://www.bbc.com/news/world/asia/china from: https://www.bbc.com/
# sentiment: (0.002955885801949585, 0.4223282172373083)
# visiting: https://www.bbc.com/news/world/asia/india from: https://www.bbc.com/
# sentiment: (0.08653803849773865, 0.4387578709169616)
# visiting: https://www.bbc.com/news/world/australia from: https://www.bbc.com/
# sentiment: (0.017810005096007955, 0.36347449145836214)
# visiting: https://www.bbc.com/news/world/europe from: https://www.bbc.com/
# sentiment: (0.0585113536748561, 0.3690848367318956)
# visiting: https://www.bbc.com/news/world/latin_america from: https://www.bbc.com/
# sentiment: (-0.018428409671186526, 0.3583064493892521)
# visiting: https://www.bbc.com/news/world/middle_east from: https://www.bbc.com/
# sentiment: (0.05523005736363802, 0.32160067574701723)
# visiting: https://www.bbc.com/news/us-canada from: https://www.bbc.com/
# sentiment: (0.040524462457642754, 0.38438183680119137)
# visiting: https://www.bbc.com/news/uk from: https://www.bbc.com/
# sentiment: (0.05947335557613603, 0.34866697275788167)
# visiting: https://www.bbc.com/news/england from: https://www.bbc.com/
# sentiment: (0.05010751750377454, 0.39954833392906786)
# visiting: https://www.bbc.com/news/northern_ireland from: https://www.bbc.com/
# sentiment: (0.03216674714374517, 0.39444789908772965)
# visiting: https://www.bbc.com/news/scotland from: https://www.bbc.com/
# sentiment: (0.05889629046136134, 0.42017323305202087)
# visiting: https://www.bbc.com/news/wales from: https://www.bbc.com/
# sentiment: (0.09206673700056824, 0.40482548907206445)
# visiting: https://www.bbc.com/news/in_pictures from: https://www.bbc.com/
# sentiment: (0.16462955153751035, 0.5016460905349792)
# visiting: https://www.bbc.com/news/reality_check from: https://www.bbc.com/
# sentiment: (0.028606504064878097, 0.3845877695877696)
# visiting: https://www.bbc.com/business/future-of-business from: https://www.bbc.com/
# sentiment: (0.057988617659606743, 0.3870003342245986)
# visiting: https://www.bbc.com/business/technology-of-business from: https://www.bbc.com/
# sentiment: (0.08521183453608065, 0.4241296849318239)
# visiting: https://www.bbc.com/business/c-suite from: https://www.bbc.com/
# sentiment: (0.04204557493389587, 0.4146983016983014)
# visiting: https://www.bbc.com/innovation/technology from: https://www.bbc.com/
# sentiment: (0.04902732052253204, 0.4286431850977302)
# visiting: https://www.bbc.com/innovation/science from: https://www.bbc.com/
# sentiment: (0.05537956728644786, 0.42126896275860004)
# visiting: https://www.bbc.com/innovation/artificial-intelligence from: https://www.bbc.com/
# sentiment: (-0.07295546537314028, 0.48057899413831595)
# visiting: https://www.bbc.com/culture/film-tv from: https://www.bbc.com/
# sentiment: (0.12188825218209726, 0.4256263754867108)
# visiting: https://www.bbc.com/culture/music from: https://www.bbc.com/
# sentiment: (0.11368147644043991, 0.39291856791856783)
# visiting: https://www.bbc.com/culture/art from: https://www.bbc.com/
# sentiment: (0.14262766475490554, 0.46670891066801834)
# visiting: https://www.bbc.com/culture/style from: https://www.bbc.com/
# sentiment: (0.148088149500914, 0.41850075094973027)
# visiting: https://www.bbc.com/culture/books from: https://www.bbc.com/
# sentiment: (0.13560611495765534, 0.389113716261367)
# visiting: https://www.bbc.com/culture/entertainment-news from: https://www.bbc.com/
# sentiment: (0.0951006612112569, 0.4176709956709954)
# visiting: https://www.bbc.com/travel/destinations from: https://www.bbc.com/
# sentiment: (0.052659274699578255, 0.432665945165945)
# visiting: https://www.bbc.com/travel/destinations/africa from: https://www.bbc.com/
# sentiment: (0.11623275305092384, 0.41255154797808796)
# visiting: https://www.bbc.com/travel/destinations/antarctica from: https://www.bbc.com/
# sentiment: (0.09839704830606003, 0.4425599929935186)
# visiting: https://www.bbc.com/travel/destinations/asia from: https://www.bbc.com/
# sentiment: (0.13459313428474196, 0.42860227272727236)
# visiting: https://www.bbc.com/travel/destinations/australia-and-pacific from: https://www.bbc.com/
# sentiment: (0.14433417707321353, 0.42150651593656735)
# visiting: https://www.bbc.com/travel/destinations/caribbean from: https://www.bbc.com/
# sentiment: (0.08567192598215892, 0.42623685837971526)
# visiting: https://www.bbc.com/travel/destinations/central-america from: https://www.bbc.com/
# sentiment: (0.078234765978827, 0.4172722567287781)
# visiting: https://www.bbc.com/travel/destinations/europe from: https://www.bbc.com/
# sentiment: (0.15326709333630165, 0.4422973388709427)
# visiting: https://www.bbc.com/travel/destinations/middle-east from: https://www.bbc.com/
# sentiment: (0.07648085411699306, 0.3797440476190473)
# visiting: https://www.bbc.com/travel/destinations/north-america from: https://www.bbc.com/
# sentiment: (0.1447829977053064, 0.44843585104779093)
# visiting: https://www.bbc.com/travel/destinations/south-america from: https://www.bbc.com/
# sentiment: (0.13547729111397755, 0.44013294711824086)
# visiting: https://www.bbc.com/travel/worlds-table from: https://www.bbc.com/
# sentiment: (0.10785015782594616, 0.4175851996642814)
# visiting: https://www.bbc.com/travel/cultural-experiences from: https://www.bbc.com/
# sentiment: (0.15017851432408041, 0.43094599688700846)
# visiting: https://www.bbc.com/travel/adventures from: https://www.bbc.com/
# sentiment: (0.09747288513735641, 0.4200167171925098)
# visiting: https://www.bbc.com/travel/specialist from: https://www.bbc.com/
# sentiment: (0.2352876877823934, 0.38462532299741564)
# visiting: https://www.bbc.com/future-planet/natural-wonders from: https://www.bbc.com/
# sentiment: (0.08405563854872364, 0.40824067000537567)
# visiting: https://www.bbc.com/future-planet/weather-science from: https://www.bbc.com/
# sentiment: (0.017314547698058947, 0.4660663638496147)
# visiting: https://www.bbc.com/future-planet/solutions from: https://www.bbc.com/
# sentiment: (0.10561094876960016, 0.4656530794135833)
# visiting: https://www.bbc.com/future-planet/sustainable-business from: https://www.bbc.com/
# sentiment: (0.08099143324546992, 0.41971278341141316)
# visiting: https://www.bbc.com/future-planet/green-living from: https://www.bbc.com/
# sentiment: (0.11293831154210221, 0.434780469859521)
# visiting: https://www.bbc.com/live/news from: https://www.bbc.com/
# sentiment: (-0.03285015375927242, 0.33378427128427146)
# visiting: https://www.bbc.com/live/sport from: https://www.bbc.com/
# sentiment: (0.09689091554162096, 0.4162812333864961)
# visiting: https://www.bbc.com/news/world-us-canada-68600093 from: https://www.bbc.com/
# sentiment: (0.058666792145053014, 0.43138643160382256)
# visiting: https://www.bbc.com/news/world-asia-68594365 from: https://www.bbc.com/
# sentiment: (-0.06009216150725585, 0.3619578534672873)
# visiting: https://www.bbc.com/news/world-latin-america-68602114 from: https://www.bbc.com/
# sentiment: (-0.026087205387205388, 0.49650808080808)
# visiting: https://www.bbc.com/news/world-europe-68601131 from: https://www.bbc.com/
# sentiment: (0.01811096577283629, 0.363578747391697)
# visiting: https://www.bbc.com/news/world-us-canada-68597752 from: https://www.bbc.com/
# sentiment: (-0.022043466737344305, 0.4039205465736079)
# visiting: https://www.bbc.com/news/world-us-canada-68602748 from: https://www.bbc.com/
# sentiment: (-0.021946407501963073, 0.39962527184749413)
# visiting: https://www.bbc.com/travel/article/20240318-what-the-3500-year-old-holiday-of-nowruz-can-teach-us-in-2024 from: https://www.bbc.com/
# sentiment: (0.11067350050368918, 0.4638524075505203)
# visiting: https://www.bbc.com/culture/article/20240318-longest-running-tv-shows-programmes-series-ever from: https://www.bbc.com/
# sentiment: (0.12098421356421363, 0.4807296488696488)
# visiting: https://www.bbc.com/travel/article/20240318-how-to-see-california-wildflower-superbloom from: https://www.bbc.com/
# sentiment: (0.15438933729821577, 0.49081731871451484)
# visiting: https://www.bbc.com/reel/video/p0hkgvzx/can-we-predict-volcanic-eruptions- from: https://www.bbc.com/
# sentiment: (0.0832481632264854, 0.4239791987673341)
# visiting: https://www.bbc.com/reel/video/p0hbhkc0/newborn-great-white-shark-caught-on-film-for-first-time- from: https://www.bbc.com/
# sentiment: (0.17507604454914424, 0.3961707103186201)
# visiting: https://www.bbc.com/reel/video/p09j5hj3/a-russian-spy-story-vladimir-putin-and-his-time-in-the-kgb from: https://www.bbc.com/
# sentiment: (0.08198563733925286, 0.3768042563497104)
# visiting: https://www.bbc.com/reel/video/p0hjprfn/why-nasa-beamed-this-cat-video-19-million-miles from: https://www.bbc.com/
# sentiment: (0.08659314168881427, 0.4192357603815935)
# visiting: https://www.bbc.com/reel/video/p0hjd77r/cape-verde-s-stunning-salt-mines from: https://www.bbc.com/
# sentiment: (0.15649870795123214, 0.47930783853293074)
# visiting: https://www.bbc.com/reel/video/p0hjls0y/does-it-really-take-10-000-steps-to-stay-healthy- from: https://www.bbc.com/
# sentiment: (0.08744360444406983, 0.40051955567580544)
# visiting: https://www.bbc.com/reel/video/p0hjmczc/what-is-the-iron-lung-and-how-does-it-work- from: https://www.bbc.com/
# sentiment: (0.09397195222618755, 0.41600645072977066)
# visiting: https://www.bbc.com/reel/video/p0hjcgw5/photos-from-the-deep-sea-show-exciting-new-species from: https://www.bbc.com/
# sentiment: (0.08262418917357682, 0.44420216929441986)
# visiting: https://www.bbc.com/reel/video/p0hj0j07/the-24-year-old-selling-human-bones from: https://www.bbc.com/
# sentiment: (0.07976978781342246, 0.37474745077735067)
# visiting: https://www.bbc.com/reel/video/p0hj8xm2/how-tumbleweed-became-an-invasive-species-in-the-us from: https://www.bbc.com/
# sentiment: (0.11067986056105011, 0.41638544536271793)
# visiting: https://www.bbc.com/reel/video/p0hj6zdf/how-a-us-tiktok-ban-will-affect-gen-z from: https://www.bbc.com/
# sentiment: (0.04998433512772415, 0.42359049680478195)
# visiting: https://www.bbc.com/reel/video/p0hhhg92/the-search-for-a-cancer-kill-switch-in-space from: https://www.bbc.com/
# sentiment: (0.0807590927095714, 0.4101934910327764)
# visiting: https://www.bbc.com/reel/video/p0hh1y8l/the-real-story-behind-oppenheimer- from: https://www.bbc.com/
# sentiment: (0.08192678669950601, 0.4434783253276401)
# visiting: https://www.bbc.com/reel/video/p0hh7cbx/the-best-and-worst-state-of-the-union-moments from: https://www.bbc.com/
# sentiment: (0.05984203867935109, 0.43395002658160514)
# visiting: https://www.bbc.com/reel/video/p0hgyrvf/the-zone-of-interest-a-personal-visit-to-auschwitz from: https://www.bbc.com/
# sentiment: (0.125389074414672, 0.45350853151177833)
# visiting: https://www.bbc.com/reel/video/p0hgsyxz/20-days-in-mariupol-the-oscars-favourite-to-win-best-doc from: https://www.bbc.com/
# sentiment: (0.1842053951029908, 0.40765311703939827)
# visiting: https://www.bbc.com/reel/video/p0hgxwqx/why-is-bitcoin-at-an-all-time-high- from: https://www.bbc.com/
# sentiment: (0.040542925314679686, 0.44080435101621507)
# visiting: https://www.bbc.com/reel/video/p0hgsj09/stunning-photos-show-the-sun-like-never-before from: https://www.bbc.com/
# sentiment: (0.11117581056689038, 0.4428868329310804)
# visiting: https://www.bbc.com/reel/video/p0hgmr29/why-we-have-hair-on-our-heads from: https://www.bbc.com/
# sentiment: (0.10009374061536325, 0.4174684017455099)
# visiting: https://www.bbc.com/reel/video/p0hgh6j2/a-brief-history-on-the-evolution-of-the-camera from: https://www.bbc.com/
# sentiment: (0.062356341640769745, 0.43386595209739265)
# visiting: https://www.bbc.com/reel/video/p0hg5g04/the-legendary-soprano-making-a-difference from: https://www.bbc.com/
# sentiment: (0.1938618606303161, 0.47052895021644997)
# visiting: https://www.bbc.com/news/world-europe-68529819 from: https://www.bbc.com/
# sentiment: (-0.03305976504371277, 0.3488231403672577)
# visiting: https://www.bbc.com/news/world-middle-east-68602337 from: https://www.bbc.com/
# sentiment: (-0.03999922648009996, 0.28965121136173766)
# visiting: https://www.bbc.com/news/world-us-canada-68570990 from: https://www.bbc.com/
# sentiment: (-0.005491475745560494, 0.3402942838084344)
# visiting: https://www.bbc.com/news/world-europe-68596923 from: https://www.bbc.com/
# sentiment: (-0.03137030788954132, 0.28322392820056375)
# visiting: https://www.bbc.com/news/world-us-canada-68559418 from: https://www.bbc.com/
# sentiment: (0.017892845854381563, 0.3756748254378582)
# visiting: https://www.bbc.com/news/business-68594141 from: https://www.bbc.com/
# sentiment: (-0.024828385899814447, 0.4180550401978973)

# %%
from pattern.web import Wikipedia, plaintext
from pattern.vector import Document, Model, KNN

# Create a model and a k-nearest neighbors classifier.
model = Model()
knn = KNN()

# Fetch the content of the Wikipedia pages of the 3 major religions.
wikipedia = Wikipedia(language="en")
religions = ["Christianity", "Islam", "Hinduism", "Secularism"]
for religion in religions:
    print(f"Fetching content for {religion}...")
    article = wikipedia.search(religion)
    if article:
        text = plaintext(article.string)
        doc = Document(text, type=religion)
        model.append(doc)

# Train the classifier on the documents in the model.
for document in model:
    knn.train(document)

# Classify a new document.
new_doc = Document('Holy spirit')
print(knn.classify(new_doc))
# Out:
# Fetching content for Christianity...
# Fetching content for Islam...
# Fetching content for Hinduism...
# Fetching content for Secularism...
# Christianity

# %%
from pattern.web import Crawler, DEPTH, plaintext
from pattern.vector import Document

class BBC_Crawler(Crawler):
    def visit(self, link, source=None):
        print("visiting: %s from: %s" % (link.url, link.referrer))
        if source:  # If the source is HTML
            text = plaintext(source)
            doc = Document(text)
            classification = knn.classify(doc)
            print(f"This page is classified as: {classification}")

    def fail(self, link):
        print("failed: %s" % link.url)

# Create a new crawler.
crawler = BBC_Crawler(links=["https://www.bbc.com/"], domains=["bbc.com"], delay=1)

while len(crawler.visited) < 100:  # Crawler.visited is a dictionary of all URL's visited so far.
    crawler.crawl(cached=True, throttle=5)
# Out:
# visiting: https://www.bbc.com/ from:
# This page is classified as: Christianity
# visiting: https://cloud.email.bbc.com/US_Election_Unspun_newsletter_signup?&at_bbc_team=studios&at_medium=display&at_objective=acquisition&at_ptr_type=&at_ptr_name=bbc.comhp&at_format=Module&at_link_origin=homepage&at_campaign=uselectionunspun&at_campaign_type=owned & from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/news from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://cloud.email.bbc.com/InHistory_newsletter_signup?&at_bbc_team=studios&at_medium=display&at_objective=acquisition&at_ptr_type=&at_ptr_name=bbc.comhp&at_format=Module&at_link_origin=homepage&at_campaign=inhistory&at_campaign_type=owned& from: https://www.bbc.com/
# This page is classified as: Islam
# visiting: https://www.bbc.com/sport from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/ from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/business from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/#MainContent from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/innovation from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/pages/customer-service from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/culture from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/new-to-the-shop from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/travel from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/new-releases from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/future-planet from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/new-apparel from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/video from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/new-home-garden from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/live from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/new-jewelry-accessories from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/home from: https://www.bbc.com/
# This page is classified as: Islam
# visiting: https://shop.bbc.com/collections/new-toys-games from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/news/topics/c2vdnvdg6xxt from: https://www.bbc.com/
# This page is classified as: Islam
# visiting: https://shop.bbc.com/pages/shows from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/news/war-in-ukraine from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/death-in-paradise from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/news/world from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/call-the-midwife from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/news/world/africa from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/father-brown from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/news/world/asia from: https://www.bbc.com/
# This page is classified as: Islam
# visiting: https://shop.bbc.com/collections/last-of-the-summer-wine from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/news/world/asia/china from: https://www.bbc.com/
# This page is classified as: Islam
# visiting: https://shop.bbc.com/collections/silent-witness from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/news/world/asia/india from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/sherlock from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/news/world/australia from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/comedy from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/news/world/europe from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/documentary from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/news/world/latin_america from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/drama from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/news/world/middle_east from: https://www.bbc.com/
# This page is classified as: Islam
# visiting: https://shop.bbc.com/collections/mystery-suspense from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/news/us-canada from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/natural-history from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/news/uk from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/science-fiction from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/news/england from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/upcoming-releases from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/news/northern_ireland from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/box-sets from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/news/scotland from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/dvds-under-25 from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/news/wales from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/dvds-under-50 from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/news/in_pictures from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/dvds-under-75 from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/news/reality_check from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/dvds-over-75 from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/business/future-of-business from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/products/ghosts-season-1-23463 from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/business/technology-of-business from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/pages/products from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/business/c-suite from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/apparel from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/innovation/technology from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/accessories from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/innovation/science from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/books from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/innovation/artificial-intelligence from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/home-garden from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/culture/film-tv from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/jewelry from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/culture/music from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/celtic-collection from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/culture/art from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/gifts-for-her from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/culture/style from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/gifts-for-him from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/culture/books from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/gifts-under-25 from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/culture/entertainment-news from: https://www.bbc.com/
# This page is classified as: Christianity
# visiting: https://shop.bbc.com/collections/gifts-under-50 from: https://shop.bbc.com/
# This page is classified as: Christianity
# visiting: https://www.bbc.com/travel/destinations from: https://www.bbc.com/
# This page is classified as: Christianity
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[13], line 20
#      17 crawler = BBC_Crawler(links=["https://www.bbc.com/"], domains=["bbc.com"], delay=1)
#      19 while len(crawler.visited) < 100:  # Crawler.visited is a dictionary of all URL's visited so far.
# ---> 20     crawler.crawl(cached=True, throttle=5)
#
# File ~/.local/lib/python3.10/site-packages/pattern/web/__init__.py:4183, in Crawler.crawl(self, method, **kwargs)
#    4181 try:
#    4182     kwargs.setdefault("unicode", True)
# -> 4183     html = url.download(**kwargs)
#    4184     for new in self.parse(html, url=link.url):
#    4185         new.url = abs(new.url, base=url.redirect or link.url)
#
# File ~/.local/lib/python3.10/site-packages/pattern/web/__init__.py:611, in URL.download(self, timeout, cached, throttle, proxy, user_agent, referrer, authentication, unicode, **kwargs)
#     609     cache[id] = data
#     610 if throttle:
# --> 611     time.sleep(max(throttle - (time.time() - t), 0))
#     612 return data
#
# KeyboardInterrupt:

# %%
from pattern.web import Google, URL, plaintext, Crawler, DEPTH
from pattern.vector import Document, Model, KNN
from config import API_KEY
from urllib.parse import urlparse

class CustomCrawler(Crawler):
    def visit(self, link, source=None):
        print(f"Visiting: {link.url} from: {link.referrer}")
        if source:  # If the source is HTML
            text = plaintext(source)
            doc = Document(text)
            model.append(doc)
            knn.train(doc)

    def fail(self, link):
        print(f"Failed: {link.url}")

# Create a model and a k-nearest neighbors classifier.
model = Model()
knn = KNN()

# Search the web for articles related to the 3 major religions.
google = Google(license=API_KEY)  # Your license key here.
religions = ["Christian", "Islamic", "Personal"]
for religion in religions:
    search_term = f"{religion} banking services"
    print(f"Searching for {search_term}...")
    for i, result in enumerate(google.search(search_term)):
        if i >= 10:  # Limit to 10 results per religion.
            break
        # Create a new crawler for each search result.
        crawler = CustomCrawler(links=[result.url], delay=1)
        # Crawl the first 10 links of each search result.
        for _ in range(10):
            crawler.crawl(cached=True, throttle=5)

# Classify a new document.
new_doc = Document('Holy spirit')
print(knn.classify(new_doc))
# Out:
# Searching for Christian banking services...
# Visiting: https://www.adelfibanking.com/ from:
# Visiting: https://www.adelfibanking.com/#content-anchor from: https://www.adelfibanking.com/
# Visiting: https://www.adelfibanking.com/personal/resources/security-and-fraud-prevention from: https://www.adelfibanking.com/
# Visiting: https://www.adelfibanking.com/logout from: https://www.adelfibanking.com/
# Visiting: https://www.adelfibanking.com/askbetter from: https://www.adelfibanking.com/
# Visiting: https://www.adelfibanking.com/personal/loans-credit-card/auto-loans from: https://www.adelfibanking.com/
# Visiting: https://www.adelfibanking.com/personal/checking-savings/checking from: https://www.adelfibanking.com/
# Visiting: https://www.adelfibanking.com/about-us from: https://www.adelfibanking.com/
# Visiting: https://www.adelfibanking.com/atms-locations from: https://www.adelfibanking.com/
# Visiting: https://www.adelfibanking.com/membership-impact from: https://www.adelfibanking.com/
# Visiting: https://www.mycccu.com/ from:
# Visiting: https://www.mycccu.com/#main from: https://www.mycccu.com/
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[2], line 35
#      33         # Crawl the first 10 links of each search result.
#      34         for _ in range(10):
# ---> 35             crawler.crawl(cached=True, throttle=5)
#      37 # Classify a new document.
#      38 new_doc = Document('Holy spirit')
#
# File ~/.local/lib/python3.10/site-packages/pattern/web/__init__.py:4183, in Crawler.crawl(self, method, **kwargs)
#    4181 try:
#    4182     kwargs.setdefault("unicode", True)
# -> 4183     html = url.download(**kwargs)
#    4184     for new in self.parse(html, url=link.url):
#    4185         new.url = abs(new.url, base=url.redirect or link.url)
#
# File ~/.local/lib/python3.10/site-packages/pattern/web/__init__.py:611, in URL.download(self, timeout, cached, throttle, proxy, user_agent, referrer, authentication, unicode, **kwargs)
#     609     cache[id] = data
#     610 if throttle:
# --> 611     time.sleep(max(throttle - (time.time() - t), 0))
#     612 return data
#
# KeyboardInterrupt:
